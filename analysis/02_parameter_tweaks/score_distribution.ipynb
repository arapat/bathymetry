# %%
import sys,os
sys.path.append('../..')
from analysis.analysistools import plot_scores, plt_score_distribution
import pickle

# %% [markdown]
# # Score distribution  -- Adjusting boosting parameters
#
# What follows are the cumulative distributions of the scores for each run. For "bad" samples, the score is plotted in blue from 1 to 0. For "good" samples, the score is plotted in red from 0 to 1. So, for a perfect classifier, you would basically have a blue peak at 0, a red peak at 1.
#
# ## Base Model
# For reference, here are models trained with the "default" boosting parameters with lat,lon,yr removed

# %%
sources = ["NGDC", "US_multi"]
base_dir = "/swot2/features/MODEL_RUNS/02_NO_LAT_LON_YR/train-test-split/runtime_scores"

# %%
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## Adjusted base parameters
#
#     1. iterations 1000 -> 200
#     2. num leaves 31 -> 7
#     3. n data per leaf 1 -> 5000

# %%
base_dir = "/swot2/features/MODEL_RUNS/03_CHANGE_PARAMS/train-test-split/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## 500 rounds

# %%
base_dir = "/swot2/features/MODEL_RUNS/07_500_ROUNDS/train-test-split/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## Feature Fraction = 0.8

# %%
base_dir = "/swot2/features/MODEL_RUNS/08_FEATURE_FRACTION/train-test-split/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## Bagging fraction = 0.8
# frequency = 25

# %%
base_dir = "/swot2/features/MODEL_RUNS/09_BAGGING_FRACTION/train-test-split/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## Extra Trees

# %%
base_dir = "/swot2/features/MODEL_RUNS/10_EXTRA_TREES/train-test-split/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## Max bins = 127

# %%
base_dir = "/swot2/features/MODEL_RUNS/11_MAX_BINS/train-test-split/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %% [markdown]
# ## learning rate and L2 regularization
# Initially, the learning rate was set at 0.01 and there were 1000 iterations. When I decreased the number of iterations to 500, I should've increased the learning rate.
#
# Finally, I added L2 regularization to the cost function with lambda_l2 = 1.0

# %%
base_dir = "/swot2/features/MODEL_RUNS/13_NO_NDP30/learning_rate/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)

# %%
base_dir = "/swot2/features/MODEL_RUNS/13_NO_NDP30/lambda_l2/runtime_scores"
for source in sources:
    path = os.path.join(base_dir, "model_{}_test_{}_scores.pkl".format(source,source))
    with open(path, 'rb') as f:
        data = pickle.load(f)
    plot_scores(data, source)
