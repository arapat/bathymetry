# %%
import numpy as np
import lightgbm
import pickle

# %%
filename = "/swot2/features/MODEL_RUNS/train-test-split/runtime_models/US_multi_model.pkl"

# %%
with open(filename,"rb") as f:
    gbm = pickle.load(f)

# %%
lightgbm.plot_tree(gbm,tree_index=1,figsize=(12,100),dpi=300)
# Out:
# <AxesSubplot:>

# %%
filename = "/geosat2/julaiti/workbox/bathymetry-analysis/runs/new-data-runs-final/runtime_models/US_multi_model.pkl"
with open(filename,"rb") as f:
    gbm = pickle.load(f)

lightgbm.plot_tree(gbm,tree_index=1,figsize=(12,100),dpi=300)
# Out:
# <AxesSubplot:>
